# %%
import uuid
print(uuid.uuid4())
# Out:
# e89dcc45-87e5-49bd-bf60-fb33524fb96d

# %%
x=open("sample_file.txt","w")

# %%
x.write("Good morning")
x.close()

# %%
x=open("sample_file.txt","r")
content=x.read()
print(content)
# Out:
# Good morning

# %%
x=open("sample_file.txt","w")
x.write("i am darvin rajesh and learning python for my skill enhancement")
x.close()
x=open("sample_file.txt","r")
content=x.read()
print(content)
x.close()
x=open("sample_file.txt","a+")
x.write("\nmy student will be brindha who is skilled in python\t")
x.close()
x=open("sample_file.txt","r")
content=x.read()
print(content)
x.close()
with open("demo.txt","w") as file:
    file.write("i am darvin rajesh and learning python for my skill enhancement")
with open("demo")
# Out:
#   File "<ipython-input-9-3f2ad3880716>", line 17
#     with open("demo.")
#                       ^
# SyntaxError: expected ':'

# %%
x=open("sample_file.txt","w")
x.write("i am darvin rajesh and learning python for my skill enhancement")
x.close()

# %%
x=open("sample_file.txt","r")
content=x.read()
print(content)
x.close()
# Out:
# i am darvin rajesh and learning python for my skill enhancement

# %%
x=open("sample_file.txt","a+")
x.write("\nmy student will be brindha who is skilled in python\t")
x.close()

# %%
x=open("sample_file.txt","r")
content=x.read()
print(content)
x.close()
# Out:
# i am darvin rajesh and learning python for my skill enhancement
# my student will be brindha who is skilled in python

# %%
with open("demo.txt","w") as file:
    file.write("i am darvin rajesh and learning python for my skill enhancement")

# %%
with open("demo.txt","r") as file:
  content=file.read()
print(content)
print(content.split(" ")[3])
# Out:
# i am darvin rajesh and learning python for my skill enhancement
# rajesh
