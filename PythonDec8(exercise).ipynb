# %%
#Program to find the area of circle
x=(int(input("Enter radius:")))
def area_of_circle(x):
  r=x**2
  area=3.14*r
  return area
area_of_circle(x)
# Out:
# Enter radius:2
# 12.56

# %%
#Program to check if a number is +, -, or 0
x=(int(input("Enter number: ")))
def num_check(x):
  if x>0:
    result=("It's positive")
  elif x<0:
    result=("It's negative")
  elif x==0:
    result=("It's zero")
  return result
num_check(x)
# Out:
# Enter number: 0
# "It's zero"

# %%
# Program to check if number is divisible by another number
a=(int(input("Enter number: ")))
b=(int(input("Enter number: ")))
def div_check(a,b):
  if a%b==0:
    result=("positive")
  else:
    result=("negative")
  return result
print(div_check(a,b))
# Out:
# Enter number: 10
# Enter number: 4
# negative

# %%
# Program that accepts n and computes value of (n+nn+nnn)
# y=(int(input("Enter number: ")))
def comp_num(x):
  result=x+x**2+x**3
  return result
print(comp_num(2))
# Out:
# 14

# %%
# Program to calculate num of days between two dates
start_date = input("Enter start date: ")
end_date = input("Enter end date: ")
def num_of_days(start_date,end_date):
  start_list=start_date.split("/")
  end_list=end_date.split("/")
  difference=(int(end_list[2])*365+int(end_list[0])*30+int(end_list[1])) - (int(start_list[2])*365+int(start_list[0])*30+int(start_list[1]))
  return difference
print(num_of_days(start_date,end_date))
# Out:
# Enter start date: 6/1/2023
# Enter end date: 12/1/2023
# 180

# %%
start_date = "10/1/2023"
end_date = "12/1/2023"
start_list=start_date.split("/")
end_list=end_date.split("/")
difference=(int(end_list[2])*365+int(end_list[0])*30+int(end_list[1])) - (int(start_list[2])*365+int(start_list[0])*30+int(start_list[1]))
print(difference)
# Out:
# 60

# %%
# Program to get the volume of a sphere
x=input("Enter radius: ")
def vol_of_sphere(x):
  try:
    r=x**3
  except:
    r=int(x)**3
  volume=(4/3)*3.14*r
  return volume
vol_of_sphere(x)
# Out:
# Enter radius: 6
# 904.3199999999999

# %%
# 1.Program which accepts the radius of a circle from the user and compute the area
# 2.Program to check if a number is positive, negative or zero
# 3.Program to check whether a number is completely divisible by another number
# 4.Program that accepts an integer (n) and computes the value of (n+nn+nnn)
# 5.Program to calculate number of days between two dates
# 6.Program to get the volume of a sphere V=4 / 3 πr3
# 7.Program to get the difference between a given number and 17, difference cannot be negative
# 8.program to get a new string from a given string where "Is" has been added to the front
# 9.Display string n times
# 10.program to find whether a given number is even or odd
# 11.program to test whether a passed letter is a vowel or not
# 12.area of a triangle
# 13.program that will return true if the two given integer values are equal or their sum or difference is 5
# 14.program to solve (x + y) * (x + y)
# 15.program to compute the future value of a specified principal amount, rate of interest, and a number of years
# 16.program to compute the distance between the points (x1, y1) and (x2, y2)
# 17.program to convert height (in feet and inches) to centimetres
# 18.program to calculate the hypotenuse of a right angled triangle
# 19.program to convert the distance (in feet) to inches, yards, and miles. 1 feet = 12 inches, 3 feet = 1 yard, 5280 feet = 1 mile
# 20.program to convert all units of time into seconds
# 21.program to reverse the digits of a given number and add it to the original, If the sum is not a palindrome repeat this procedure
# 22.program to get the Fibonacci series between 0 to 50
# 23.program to create the multiplication table (from 1 to 10) of a number
# 24.sum of first n positive integers
# 25.program that accepts a string and calculate the number of digits and letters
# 26.integer conversion to binary, octal and hexadecimal
# 27.binary to decimal conversion
# 28.octal to decimal conversion
# 29.hexa-decimal to decimal conversion
# 30.to count the occurence of a specific character in a string
# 31.GCD (Greatest Common Divisor)
# 32.LCM (Least Common Multiple)
# 33.to find the number of notes (Sample of notes: 10, 20, 50, 100, 500, and 1000 ) against an given amount34.count vowels / consonants

# %%
# 7)
x=int(input("Enter number: "))
def diff_of_nums(x):
  difference = 17 - x
  if difference>0:
    print("it works")
    print(difference)
  else:
    print("it does not work")
diff_of_nums(x)
# Out:
# Enter number: 23
# it does not work

# %%
# 8.program to get a new string from a given string where "Is" has been added to the front
x = input("Enter answer: ")
def string_change(x):
  new_string = "Is "+x
  return new_string
print(string_change(x))
# Out:
# Enter answer: That's red
# Is That's red

# %%
# 9.Display string n times
string = "I love chocolate"
num = 3
for i in range(num):
  print(string,end = " ")
# Out:
# I love chocolate I love chocolate I love chocolate

# %%
print(num*(string+"\n"))
# Out:
# I love chocolate
# I love chocolate
# I love chocolate

# %%
# 10.program to find whether a given number is even or odd
num = 22
def num_check(num):
  if num%2 == 0:
    output = ("The number is even")
  else:
    output = ("The number is odd")
  return output
print(num_check(num))
# Out:
# The number is even

# %%
print(10%3)
# Out:
# 1

# %%
# 11.program to test whether a passed letter is a vowel or not
letter = "w"
def vowel_check(letter):
  if letter in ["a","e","i","o","u"]:
    output = "Letter is a vowel"
  else:
    output = "Letter is not a vowel"
  return output
print(vowel_check(letter))
# Out:
# Letter is not a vowel

# %%
# 12.area of a triangle
length = 6
width = 4
def area_of_triangle(length, width):
  area = (length * width)/2
  return area
print(area_of_triangle(length, width))
# Out:
# 12.0

# %%
# 13.program that will return true if the two given integer values are equal or their sum or difference is 5
value_1 = 7
value_2 = -2
def int_check(value_1, value_2):
  if value_1 == value_2:
    result=("true")
  elif value_1 - value_2 == 5:
    result=("true")
  elif value_1 + value_2 == 5:
    result=("true")
  else:
    result=("false")
  return result
int_check(value_1, value_2)
# Out:
# 'true'

# %%
# 14.program to solve (x + y) * (x + y)
x = 4
y = 2
def solve_equation(x,y):
  result = x * x + 2 * x * y + y * y
  return result
solve_equation(x,y)
# Out:
# 36

# %%
# 15.program to compute the future value of a specified principal amount, rate of interest, and a number of years

# %%
principal_amount = 1000
rate_of_interest = 0.04
num_of_years = 4
n = 4
t = 3
def future_value(principal_amount, rate_of_interest, num_of_years,n,t):
  com_interest = principal_amount*(1 + rate_of_interest/n)**(n*t)
  return com_interest
future_value(principal_amount, rate_of_interest, num_of_years,n,t)
# Out:
# 1126.8250301319697

# %%
# 16.program to compute the distance between the points (x1, y1) and (x2, y2)
x1 = 3
x2 = 4
y1 = 2
y2 = 5
def point_distance(x1, x2, y1, y2):
  distance = ((x2 - x1)**2 + (y2 - y1)**2)**1/2
  return distance
point_distance(x1, x2, y1, y2)
# Out:
# 5.0

# %%
# 17.program to convert height (in feet and inches) to centimetres
type_height = input("Enter feet or inches: ")
height = input("Enter height: ")
def convert_height(type_height, height):
  if type_height == "feet":
    result = int(height) * 30.14
  elif type_height == "inches":
    result = int(height) * 2.54
  return result
convert_height(type_height, height)
# Out:
# Enter feet or inches: inches
# Enter height: 5
# 12.7

# %%
# 18.program to calculate the hypotenuse of a right angled triangle
side_1 = input("Enter side length: ")
side_2 = input("Enter side length: ")
def cal_hypotenuse(side_1, side_2):
  hypotenuse = (int(side_1)**2 + int(side_2)**2)**0.5
  return hypotenuse
cal_hypotenuse(side_1, side_2)
# Out:
# Enter side length: 3
# Enter side length: 4
# 5.0

# %%
# 19.program to convert the distance (in feet) to inches, yards, and miles. 1 feet = 12 inches, 3 feet = 1 yard, 5280 feet = 1 mile
type_distance = input("Enter inches, yards, or miles: ")
distance = input("Enter distance: ")
def convert_distance(type_distance, distance):
  if type_distance == "inches":
    result = int(distance) * 12
  elif type_distance == "yards":
    result = int(distance) * 3
  elif type_distance == "miles":
    result = int(distance) * 5280
  return result
convert_distance(type_distance, distance)
# Out:
# Enter inches, yards, or miles: inches
# Enter distance: 5
# 60

# %%
# 20.program to convert all units of time into seconds
type_unit = input("Enter seconds, minutes, or hours: ")
time = input("Enter time: ")
def convert_time(type_unit, time):
  if type_unit == "seconds":
    result = int(time) * 1
  elif type_unit == "minutes":
    result = int(time) * 60
  elif type_unit == "hours":
    result = int(time) * 3600
  return result
convert_time(type_unit, time)
# Out:
# Enter seconds, minutes, or hours: minutes
# Enter time: 5
# 300

# %%
time = "3:5:25"
def convert_time(time):
  time_list = time.split(":")
  result = int(time_list[0]) * 3600 + int(time_list[1]) * 60 + int(time_list[2]) * 1
  return result
print(convert_time(time))
# Out:
# 11125

# %%
# 21.program to reverse the digits of a given number and add it to the original, If the sum is not a palindrome repeat this procedure
number = input("Enter number: ")
def reverse_num(number):
  reverse_number = (number[::-1])
  new_num = int(number) + int(reverse_number)
  print(new_num)
  return reverse_number
reverse_num(number)
# Out:
# Enter number: 1234
# 5555
# '4321'

# %%
# 22.program to get the Fibonacci series between 0 to 50
number = 50
def fibo_series(number):
  num_1 = 0
  num_2 = 1
  next_num = num_2
  count = 1
  while count:
    print(next_num)
    count = count + 1
    num_1, num_2 = num_2, next_num
    next_num = num_1 + num_2
    if next_num > 50:
      break
fibo_series(number)
# Out:
# 1
# 2
# 3
# 5
# 8
# 13
# 21
# 34

# %%
# 23.program to create the multiplication table (from 1 to 10) of a number
number = 6
def multi_table(number):
  for i in range(1,11):
    print(f"{i}*{number}={i*number}")
multi_table(number)
# Out:
# 1*6=6
# 2*6=12
# 3*6=18
# 4*6=24
# 5*6=30
# 6*6=36
# 7*6=42
# 8*6=48
# 9*6=54
# 10*6=60

# %%
# 24.sum of first n positive integers
x = int(input("Enter list of numbers: "))
def sum_of_nums(x):
  sum = 0
  for i in range(x+1):
    sum = sum + i
  return sum
sum_of_nums(x)
# Out:
# Enter list of numbers: 5
# 15

# %%
# 25.program that accepts a string and calculate the number of digits and letters
string = input("Enter something: ")
def string_calc(string):
  letters = 0
  digits = 0
  for i in string:
    if i.isalpha():
      letters = letters + 1
    elif i.isdigit():
      digits = digits + 1
  return letters, digits
print("(Letters, Digits): ",string_calc(string))
# Out:
# Enter something: 23gty567
# (Letters, Digits):  (3, 5)

# %%
# 26.integer conversion to binary, octal and hexadecimal
integar = int(input("Enter integar: "))
conversion = input("Choose either binary, octal, or hexadecimal: ")
def int_convers(integar):
  if conversion == "octal":
    converse = oct(integar)
  elif conversion == "binary":
    converse = bin(integar)
  elif conversion == "hexadecimal":
    converse = hex(integar)
  return converse
int_convers(integar)
# Out:
# Enter integar: 12
# Choose either binary, octal, or hexadecimal: binary
# '0b1100'

# %%
# 27.binary to decimal conversion
integar = int(input("Enter binary: "))
binary = str(bin(integar)[2:])
def bin_conv(binary):
  output = int(binary,2)
  return output
bin_conv(binary)
# Out:
# Enter binary: 23
# 23

# %%
# 28.octal to decimal conversion
integar = int(input("Enter octal: "))
octal = str(oct(integar)[2:])
def oct_conv(octal):
  output = int(octal,8)
  return output
oct_conv(octal)
# Out:
# Enter octal: 12
# 12

# %%
# 29.hexa-decimal to decimal conversion
integar = int(input("Enter number: "))
hexa_dec = str(hex(integar)[2:])
def hex_conv(hexa_dec):
  output = int(hexa_dec,16)
  return output
hex_conv(hexa_dec)
# Out:
# Enter number: 12
# 12

# %%
# 30.to count the occurence of a specific character in a string
string = input("Enter string: ")
specific_charc = input("Enter specific character: ")
def occ_count(string):
  characters = 0
  for i in string:
    if i == specific_charc:
      characters = characters + 1
  return characters
occ_count(string)
# Out:
# Enter string: chocolate
# Enter specific character: t
# 1

# %%
# 31.GCD (Greatest Common Divisor)
print('To find GCD enter ')
num1 = int(input('number 1 : '))
num2 = int(input('number 2 : '))
if num1 > num2:
        greater = num2
else:
        greater = num1
for i in range(1, greater+1):
    if((num1 % i == 0) and (num2 % i == 0)):
        gcd = i
print('The gcd of' , num1 , 'and' , num2 , 'is' , gcd)
# Out:
# To find GCD enter
# number 1 : 12
# number 2 : 24
# The gcd of 12 and 24 is 12

# %%
# 32.LCM (Least Common Multiple)
print('To find LCM enter ')
num1 = int(input('number 1 : '))
num2 = int(input('number 2 : '))
if num1 > num2:
        lesser = num1
else:
        lesser = num2
while True:
    if(lesser % num1 == 0 and lesser % num2 == 0):
        lcm = lesser
        break
    lesser += 1

print('The lcm of' , num1 , 'and' , num2 , 'is' , lcm)
# Out:
# To find LCM enter
# number 1 : 12
# number 2 : 36
# The lcm of 12 and 36 is 36

# %%
# 33.to find the number of notes (Sample of notes: 10, 20, 50, 100, 500, and 1000 ) against an given amount
amount = int(input("Enter a number: "))
def num_of_notes(amount):
  count_1000 = 0
  count_500 = 0
  count_100 = 0
  count_50 = 0
  count_20 = 0
  count_10 = 0
  if amount>1000:
    count_1000 = amount//1000
    reminder = amount%1000
  if reminder > 500:
    count_500 = reminder//500
    reminder = reminder%500
  if reminder > 100:
    count_100 = reminder//100
    reminder = reminder%100
  if reminder > 50:
    count_50 = reminder//50
    reminder = reminder%50
  if reminder > 20:
    count_20 = reminder//20
    reminder = reminder%20
  if reminder >= 10:
    count_10 = reminder//10
  return count_1000, count_500, count_100, count_50, count_20, count_10
num_of_notes(amount)
# Out:
# Enter a number: 3110
# (3, 0, 1, 0, 0, 1)

# %%
# 34.count vowels / consonants
word = input("Enter a word: ")
def count_vowel(word):
  vowels = ["a","e","i","o","u","A","E","I","O","U"]
  count_vowels = 0
  count_consonants = 0
  for alphabet in word:
    if alphabet in vowels:
      count_vowels = count_vowels + 1
    else:
      count_consonants = count_consonants + 1
  return count_vowels, count_consonants
count_vowel(word)
# Out:
# Enter a word: chocolate
# (4, 5)
