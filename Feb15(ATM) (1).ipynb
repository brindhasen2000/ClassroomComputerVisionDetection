# %%
options = "Enter your operations\nEnter 1 to check balance\nEnter 2 to withdraw\nEnter 3 to deposit\nEnter 4 to change pin\nEnter 5 to exit"
print(options)
user_input = input()
# Out:
# Enter your operations
# Enter 1 to check balance
# Enter 2 to withdraw
# Enter 3 to deposit
# Enter 4 to change pin
# Enter 5 to exit
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-27c458d5488d> in <cell line: 3>()
#       1 options = "Enter your operations\nEnter 1 to check balance\nEnter 2 to withdraw\nEnter 3 to deposit\nEnter 4 to change pin\nEnter 5 to exit"
#       2 print(options)
# ----> 3 user_input = input()
#
# TypeError: 'str' object is not callable
