# %%
A=True
if A!=True:
  print ("Hello")
else:
  print("Bye")
# Out:
# Bye

# %%
#if elif else sample
num_1=7
num_2=25
if num_1>num_2:
  print("Brindha")
elif num_1==num_2:
  print("Darvin")
else:
  a=20+20
  txt="Senthil {} age old"
  print(txt.format(a))
# Out:
# Senthil 40 age old

# %%
#For Loop Sample
a=["red", "blue", "green"]
for x in a:
  print("Senthil "+x)
# Out:
# Senthil red
# Senthil blue
# Senthil green

# %%
str_1="My name is Brindha"
str_2="I am learning Python"
print(str_1[11:18])
print(str_2[14:20])
# Out:
# Brindha
# Python

# %%
print(str_1.lower())
# Out:
# my name is brindha

# %%
print(str_1.upper())
# Out:
# MY NAME IS BRINDHA

# %%
print(str_1.capitalize())
# Out:
# My name is brindha

# %%
print(str_1.casefold())
# Out:
# my name is brindha

# %%
str_3="Helloworld1"
print(str_3.islower())
# Out:
# False

# %%
print(str_3.isupper())
# Out:
# False

# %%
print(str_3.startswith("hell"))
# Out:
# False

# %%
print(str_3.endswith("worl"))
# Out:
# False

# %%
print(str_3.count("o"))
# Out:
# 2

# %%
print(str_3.isspace())
# Out:
# False

# %%
print(str_3.isalpha())
# Out:
# True

# %%
print(str_3.isdigit())
# Out:
# False

# %%
print(str_3.isalnum())
# Out:
# True

# %%
str_4="I am Brindha"
list_1=str_4.split(" ")

# %%
print(list_1)
# Out:
# ['I', 'am', 'Brindha']

# %%
print(list_1[2])
# Out:
# Brindha

# %%
print(str_4.replace("Brindha","Darvin"))
# Out:
# I am Darvin

# %%
print(str_4.replace("I","You"))
# Out:
# You am Brindha

# %%
str_5=" Hello World "
print(str_5.strip())
# Out:
# Hello World

# %%
print(str_5.lstrip())
# Out:
# Hello World

# %%
print(str_5.rstrip())
# Out:
#  Hello World

# %%
print(str_1+","+str_2)
# Out:
# My name is Brindha,I am learning Python
