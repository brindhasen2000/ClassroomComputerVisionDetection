# %%
list_1=["I","am","Brindha","I","am","using","python"]
for n in list_1:
  print(n,end=" ")
# Out:
# I am Brindha I am using python

# %%
for i in range(len(list_1)):
  print(list_1[i],end=" ")
# Out:
# I am Brindha I am using python

# %%
for idx,element in enumerate(list_1):
  print(idx,element)
# Out:
# 0 I
# 1 am
# 2 Brindha
# 3 I
# 4 am
# 5 using
# 6 python

# %%
a=True
while a==True:
  i=input("Enter:")
  if i=="10":
    a=False
# Out:
# Enter:red
# Enter:10
