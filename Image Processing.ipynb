# %%
import cv2
import numpy as np

image = cv2.imread('cute_dog.webp')


# width = image.shape[1]
# height = image.shape[0]

print(image)

# # ## Image Resizing

# new_height = int(height*3)
# new_width = int(width*2)
# zoomed_image = cv2.resize(src =image,
# 						dsize=(new_width, new_height),
# 						interpolation=cv2.INTER_CUBIC)
# cv2.imwrite("./output_images/resized_image.png", zoomed_image)



# # #Image Rotation

# center = (image.shape[1] // 2, image.shape[0] // 2)
# angle = 30
# scale = 1
# rotation_matrix = cv2.getRotationMatrix2D(center, angle, scale)
# rotated_image = cv2.warpAffine(image, rotation_matrix, (image.shape[1], image.shape[0]))
# cv2.imwrite("./output_images/rotated_image.png", rotated_image)



## Image Translation

# tx = 100
# ty = 70
# translation_matrix = np.array([[1, 0, tx], [0, 1, ty]], dtype=np.float32)
# translated_image = cv2.warpAffine(image, translation_matrix, (width, height))
# cv2.imwrite("./output_images/translation_image.png", translated_image)




# ## Image Shearing

# shearX = -0.15
# shearY = 0
# transformation_matrix = np.array([[1, shearX, 0],
# 								[0, 1, shearY]], dtype=np.float32)
# sheared_image = cv2.warpAffine(image, transformation_matrix, (width, height))
# cv2.imwrite("./output_images/sheared_image.png", sheared_image)



## Edge detection in an Image

# edges = cv2.Canny(image= image, threshold1=100, threshold2=700)
# cv2.imwrite("./output_images/edges_image.png", edges)


# ## Image Blurring

# blurred = cv2.GaussianBlur(image, (3, 3), 5)
# cv2.imwrite("./output_images/blurred_image.png", blurred)
# Out:
# None

# %%
pip install opencv-python
