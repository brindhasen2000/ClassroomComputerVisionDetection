# %%
str_1="My name is Brindha"
str_2="I am in 9th grade"
str_3="I love football"
print(str_1+", "+str_2+", "+str_3)
# Out:
# My name is Brindha, I am in 9th grade, I love football

# %%
name="Brindha"
grade=9
game="football"

print("My name is "+name+", "+"I am in grade "+str(grade)+", "+"I love "+game)
# Out:
# My name is Brindha, I am in grade 9, I love football

# %%
print(f"My name is {name}, I am in grade {str(grade)}, I love {game}")
# Out:
# My name is Brindha, I am in grade 9, I love football

# %%
print("My name is {n}, I am in grade {g}, I love {j}".format(n=name,g=grade,j=game))
# Out:
# My name is Brindha, I am in grade 9, I love football

# %%
print("My name is, ",name," I am in grade" ,str(grade),", I love ",game)
# Out:
# My name is,  Brindha  I am in grade 9 , I love  football

# %%
print("My name is %s, I am in grade %s, I love %s"%(name,grade,game))
# Out:
# My name is Brindha, I am in grade 9, I love football

# %%
def square_of_number(num):
  squared_number=num**2
  return squared_number

square_of_number(10)
# Out:
# 100
