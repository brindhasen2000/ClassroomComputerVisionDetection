# %%
my_dictionary={"name":"Brindha","age":14,"school":"American High School","subject":["math","english","science"]}
print(my_dictionary)
print(type(my_dictionary))
print(my_dictionary["age"])
print(my_dictionary["subject"][1])
print(type(my_dictionary["subject"]))
print(my_dictionary.get("father's name","Brindha"))
# Out:
# {'name': 'Brindha', 'age': 14, 'school': 'American High School', 'subject': ['math', 'english', 'science']}
# <class 'dict'>
# 14
# english
# <class 'list'>
# Brindha

# %%
my_dictionary={"name":"Brindha","age":14,"school":"American High School","subject":["math","english","science"]}
my_dictionary.update({"father's name":"SenthilKumar","mother's name":"Sasireka"})
print(my_dictionary.keys())
print(my_dictionary.values())
print(my_dictionary.items())
# Out:
# dict_keys(['name', 'age', 'school', 'subject', "father's name", "mother's name"])
# dict_values(['Brindha', 14, 'American High School', ['math', 'english', 'science'], 'SenthilKumar', 'Sasireka'])
# dict_items([('name', 'Brindha'), ('age', 14), ('school', 'American High School'), ('subject', ['math', 'english', 'science']), ("father's name", 'SenthilKumar'), ("mother's name", 'Sasireka')])

# %%
for k,v in my_dictionary.items():
  if v=="Brindha":
    print(k)
# Out:
# name

# %%
my_dictionary["age"]=15
print(my_dictionary)
# Out:
# {'name': 'Brindha', 'age': 15, 'school': 'American High School', 'subject': ['math', 'english', 'science'], "father's name": 'SenthilKumar', "mother's name": 'Sasireka'}

# %%
my_dictionary["subject"].append("french")
print(my_dictionary)
# Out:
# {'name': 'Brindha', 'age': 15, 'school': 'American High School', 'subject': ['math', 'english', 'science', 'french'], "father's name": 'SenthilKumar', "mother's name": 'Sasireka'}

# %%
my_dictionary["name"]="Brindha Kumar"
print(my_dictionary)
# Out:
# {'name': 'Brindha Kumar', 'age': 15, 'school': 'American High School', 'subject': ['math', 'english', 'science', 'french'], "father's name": 'SenthilKumar', "mother's name": 'Sasireka'}

# %%
my_dictionary.pop("age")
print(my_dictionary)
# Out:
# {'name': 'Brindha Kumar', 'school': 'American High School', 'subject': ['math', 'english', 'science', 'french'], "father's name": 'SenthilKumar', "mother's name": 'Sasireka'}

# %%
my_dictionary.popitem()
print(my_dictionary)
# Out:
# {'name': 'Brindha Kumar', 'school': 'American High School', 'subject': ['math', 'english', 'science', 'french'], "father's name": 'SenthilKumar'}

# %%
del my_dictionary["father's name"]
print(my_dictionary)
# Out:
# {'name': 'Brindha Kumar', 'school': 'American High School', 'subject': ['math', 'english', 'science', 'french']}

# %%
b=my_dictionary.copy()
print(my_dictionary)
# Out:
# {'name': 'Brindha Kumar', 'school': 'American High School', 'subject': ['math', 'english', 'science', 'french']}

# %%
print(b)
# Out:
# {'name': 'Brindha Kumar', 'school': 'American High School', 'subject': ['math', 'english', 'science', 'french']}

# %%
my_dictionary.clear()
print(my_dictionary)
# Out:
# {}

# %%
my_dictionary["name"]="brindha"
print(my_dictionary)
# Out:
# {'name': 'brindha'}

# %%
job_dictionary={"name":"Senthil Kumar","job":"software engineer","date joined":2014,"years of working":9,"skills":["Java","Python","HTML","etc."]}
job_dictionary["job"]="senior software engineer"
job_dictionary["years of working"]=10
job_dictionary["skills"].append("C++")
print(job_dictionary)
# Out:
# {'name': 'Senthil Kumar', 'job': 'senior software engineer', 'date joined': 2014, 'years of working': 10, 'skills': ['Java', 'Python', 'HTML', 'etc.', 'C++']}
